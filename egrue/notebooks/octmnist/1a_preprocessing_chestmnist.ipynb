# %%
# %load_ext autoreload
# %autoreload 2

import sys

# Import Functions
sys.path.append("../../")

from medmnist import ChestMNIST
from torchvision import transforms

from src.configs.chestmnist_config import data_name
from src.file_manager.filepath import FilePath
from src.display.display_image import show_img_examples_ds, get_image_class_distribution_labels
from src.data_generator.chest_mnist import load_chestmnist_data_dict


seed=2024
fp = FilePath(data_name=data_name, seed=seed)

# %% [markdown]
# # Load Data

# %%
data_dict = load_chestmnist_data_dict(fp_preprocessed=fp.get_preprocessed_folder())

# %% [markdown]
# # Class Distribution

# %%
get_image_class_distribution_labels(data_dict)

# %% [markdown]
# # Image Statistics

# %%
from tqdm.auto import tqdm
import numpy as np
all_min, all_max = np.inf, -np.inf
for x, y in tqdm(data_dict["train_df"]):
    all_min = min(all_min, x.min())
    all_max = max(all_max, x.max())
print(all_min, all_max)

# %% [markdown]
# # Display Image

# %%
show_img_examples_ds(
    data_dict["train_df"], num_classes=2, 
    classes=[i for i in range(2)], ncols=2, transform=False
)
